# %%
pip install yfinance

# %%
import yfinance as yf
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
d=yf.download('TATAMOTORS.NS',start='2003-10-01',interval='1d')
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
d=yf.download('ASTRAL.NS',start='2003-10-01',interval='1d')
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
d=yf.download('3MINDIA.NS',start='2011-10-11',interval='1d')
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
d
# Out:
#                     Open          High  ...     Adj Close  Volume
# Date                                    ...
# 2011-10-11   4320.000000   4492.000000  ...   4263.000000     192
# 2011-10-12   4308.000000   4308.000000  ...   4269.799805     234
# 2011-10-13   4299.899902   4325.000000  ...   4312.500000     388
# 2011-10-14   4304.399902   4305.000000  ...   4260.450195     446
# 2011-10-17   4285.000000   4389.950195  ...   4355.350098     360
# ...                  ...           ...  ...           ...     ...
# 2021-12-15  24935.000000  25440.000000  ...  24668.750000    5887
# 2021-12-16  24750.000000  25041.300781  ...  24926.599609    2818
# 2021-12-17  25040.000000  25040.000000  ...  24536.099609    4205
# 2021-12-20  24401.000000  24515.800781  ...  23812.949219    5083
# 2021-12-21  24150.900391  24280.000000  ...  24181.250000    2952
#
# [2511 rows x 6 columns]

# %%
d
# Out:
#                     Open          High  ...     Adj Close  Volume
# Date                                    ...
# 2011-10-11   4320.000000   4492.000000  ...   4263.000000     192
# 2011-10-12   4308.000000   4308.000000  ...   4269.799805     234
# 2011-10-13   4299.899902   4325.000000  ...   4312.500000     388
# 2011-10-14   4304.399902   4305.000000  ...   4260.450195     446
# 2011-10-17   4285.000000   4389.950195  ...   4355.350098     360
# ...                  ...           ...  ...           ...     ...
# 2021-12-15  24935.000000  25440.000000  ...  24668.750000    5887
# 2021-12-16  24750.000000  25041.300781  ...  24926.599609    2818
# 2021-12-17  25040.000000  25040.000000  ...  24536.099609    4205
# 2021-12-20  24401.000000  24515.800781  ...  23812.949219    5083
# 2021-12-21  24150.900391  24280.000000  ...  24181.250000    2952
#
# [2511 rows x 6 columns]

# %%
d['Moving average']=d.Close.rolling(50).mean()

# %%
d['std']=d.Close.rolling(50).std()

# %%
d
# Out:
#                     Open          High  ...  Moving average         std
# Date                                    ...
# 2011-10-11   4320.000000   4492.000000  ...             NaN         NaN
# 2011-10-12   4308.000000   4308.000000  ...             NaN         NaN
# 2011-10-13   4299.899902   4325.000000  ...             NaN         NaN
# 2011-10-14   4304.399902   4305.000000  ...             NaN         NaN
# 2011-10-17   4285.000000   4389.950195  ...             NaN         NaN
# ...                  ...           ...  ...             ...         ...
# 2021-12-15  24935.000000  25440.000000  ...    25800.458086  643.584793
# 2021-12-16  24750.000000  25041.300781  ...    25790.272070  653.427486
# 2021-12-17  25040.000000  25040.000000  ...    25775.903047  673.053267
# 2021-12-20  24401.000000  24515.800781  ...    25746.371016  725.203370
# 2021-12-21  24150.900391  24280.000000  ...    25725.363008  755.019612
#
# [2511 rows x 8 columns]

# %%
d=d[['Close','Moving average','std']]

# %%
d
# Out:
#                    Close  Moving average         std
# Date
# 2011-10-11   4263.000000             NaN         NaN
# 2011-10-12   4269.799805             NaN         NaN
# 2011-10-13   4312.500000             NaN         NaN
# 2011-10-14   4260.450195             NaN         NaN
# 2011-10-17   4355.350098             NaN         NaN
# ...                  ...             ...         ...
# 2021-12-15  24668.750000    25800.458086  643.584793
# 2021-12-16  24926.599609    25790.272070  653.427486
# 2021-12-17  24536.099609    25775.903047  673.053267
# 2021-12-20  23812.949219    25746.371016  725.203370
# 2021-12-21  24181.250000    25725.363008  755.019612
#
# [2511 rows x 3 columns]

# %%
d['upper_band1']=d['Moving average']+0.5*d['std']
d['lower_band1']=d['Moving average']-0.2*d['std']
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
d['upper_band']=d['Moving average']+1.5*d['std']
d['lower_band']=d['Moving average']-1.5*d['std']
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
d
# Out:
#                    Close  Moving average  ...    upper_band    lower_band
# Date                                      ...
# 2011-10-11   4263.000000             NaN  ...           NaN           NaN
# 2011-10-12   4269.799805             NaN  ...           NaN           NaN
# 2011-10-13   4312.500000             NaN  ...           NaN           NaN
# 2011-10-14   4260.450195             NaN  ...           NaN           NaN
# 2011-10-17   4355.350098             NaN  ...           NaN           NaN
# ...                  ...             ...  ...           ...           ...
# 2021-12-15  24668.750000    25800.458086  ...  26765.835275  24835.080897
# 2021-12-16  24926.599609    25790.272070  ...  26770.413299  24810.130842
# 2021-12-17  24536.099609    25775.903047  ...  26785.482947  24766.323147
# 2021-12-20  23812.949219    25746.371016  ...  26834.176070  24658.565961
# 2021-12-21  24181.250000    25725.363008  ...  26857.892426  24592.833590
#
# [2511 rows x 7 columns]

# %%
e=d[['Close','upper_band1','lower_band1']]

# %%
f=d[['Close','spl']]

# %%
plt.plot(e)

# %%
plt.figure(figsize=(30, 30))
plt.plot(e)
plt.show()
plt
# Out:
# <module 'matplotlib.pyplot' from '/usr/local/lib/python3.7/dist-packages/matplotlib/pyplot.py'>

# %%
e
# Out:
#                    Close   upper_band1   lower_band1
# Date
# 2011-10-11   4263.000000           NaN           NaN
# 2011-10-12   4269.799805           NaN           NaN
# 2011-10-13   4312.500000           NaN           NaN
# 2011-10-14   4260.450195           NaN           NaN
# 2011-10-17   4355.350098           NaN           NaN
# ...                  ...           ...           ...
# 2021-12-15  24668.750000  26122.250482  25671.741127
# 2021-12-16  24926.599609  26116.985813  25659.586573
# 2021-12-17  24536.099609  26112.429680  25641.292394
# 2021-12-20  23812.949219  26108.972701  25601.330342
# 2021-12-21  24181.250000  26102.872814  25574.359085
#
# [2511 rows x 3 columns]

# %%
l12=[]
l12=e.index

# %%
l12
# Out:
# DatetimeIndex(['2011-10-11', '2011-10-12', '2011-10-13', '2011-10-14',
#                '2011-10-17', '2011-10-18', '2011-10-19', '2011-10-20',
#                '2011-10-21', '2011-10-24',
#                ...
#                '2021-12-08', '2021-12-09', '2021-12-10', '2021-12-13',
#                '2021-12-14', '2021-12-15', '2021-12-16', '2021-12-17',
#                '2021-12-20', '2021-12-21'],
#               dtype='datetime64[ns]', name='Date', length=2511, freq=None)

# %%
e.index=range(0,len(e))

# %%
e
# Out:
#              Close   upper_band1   lower_band1
# 0      4263.000000           NaN           NaN
# 1      4269.799805           NaN           NaN
# 2      4312.500000           NaN           NaN
# 3      4260.450195           NaN           NaN
# 4      4355.350098           NaN           NaN
# ...            ...           ...           ...
# 2506  24668.750000  26122.250482  25671.741127
# 2507  24926.599609  26116.985813  25659.586573
# 2508  24536.099609  26112.429680  25641.292394
# 2509  23812.949219  26108.972701  25601.330342
# 2510  24181.250000  26102.872814  25574.359085
#
# [2511 rows x 3 columns]

# %%
e['upper_band1'][2]
# Out:
# nan

# %%
c=100000
t=0
shares=1
shares1=1
short=0
pr=0
p=0

# %%
asd=[]
qwe=[]

# %%
for i in range(51,2470):
  if e['lower_band1'][i-1]>e['Close'][i-1] and e['lower_band1'][i]<e['Close'][i]:
    p=1
    shares=int(c/e['Close'][i])
  if e['upper_band1'][i-1]<e['Close'][i-1] and e['upper_band1'][i]>e['Close'][i]:
    pr=e['Close'][i]*shares
    p=0
    c=pr
    asd.append([l12[i],c,pr,shares,e['Close'][i],'long'])
    qwe.append(i)
    print(c,shares,i,e['Close'][i],'long')
# Out:
# 97139.25 27 74 3597.75 long
# 98326.80126953125 26 104 3781.800048828125 long
# 98072.0 26 106 3772.0 long
# 104198.8974609375 26 130 4007.64990234375 long
# 103561.8974609375 26 135 3983.14990234375 long
# 102616.20263671875 27 196 3800.60009765625 long
# 108454.95263671875 27 240 4016.85009765625 long
# 107684.10131835938 27 244 3988.300048828125 long
# 103521.6025390625 26 280 3981.60009765625 long
# 103386.3974609375 26 310 3976.39990234375 long
# 104564.19873046875 26 312 4021.699951171875 long
# 103757.65283203125 29 397 3577.85009765625 long
# 102109.0 29 404 3521.0 long
# 100953.6015625 32 512 3154.800048828125 long
# 99515.203125 32 516 3109.85009765625 long
# 98580.0 31 518 3180.0 long
# 113460.0 31 582 3660.0 long
# 112598.19848632812 31 585 3632.199951171875 long
# 113904.85302734375 31 588 3674.35009765625 long
# 114076.89697265625 31 594 3679.89990234375 long
# 111125.69848632812 31 598 3584.699951171875 long
# 181998.0029296875 30 739 6066.60009765625 long
# ...

# %%
c
# Out:
# 715883.861328125

# %%
c/100000
# Out:
# 7.15883861328125

# %%
asd
# Out:
# [[Timestamp('2012-01-31 00:00:00'), 97139.25, 97139.25, 27, 3597.75, 'long'],
#  [Timestamp('2012-03-15 00:00:00'),
#   98326.80126953125,
#   98326.80126953125,
#   26,
#   3781.800048828125,
#   'long'],
#  [Timestamp('2012-03-19 00:00:00'), 98072.0, 98072.0, 26, 3772.0, 'long'],
#  [Timestamp('2012-04-24 00:00:00'),
#   104198.8974609375,
#   104198.8974609375,
#   26,
#   4007.64990234375,
#   'long'],
#  [Timestamp('2012-05-02 00:00:00'),
#   103561.8974609375,
#   103561.8974609375,
#   26,
#   3983.14990234375,
#   'long'],
#  [Timestamp('2012-07-26 00:00:00'),
#   102616.20263671875,
#   102616.20263671875,
#   27,
#   3800.60009765625,
#   'long'],
#  [Timestamp('2012-10-01 00:00:00'),
#   108454.95263671875,
#   108454.95263671875,
#   27,
#   4016.85009765625,
#   'long'],
#  [Timestamp('2012-10-08 00:00:00'),
#   107684.10131835938,
#   107684.10131835938,
#   27,
#   3988.300048828125,
#   'long'],
#  [Timestamp('2012-12-04 00:00:00'),
#   103521.6025390625,
# ...

# %%
qa=pd.DataFrame(asd)

# %%
qa
# Out:
#             0              1              2   3             4     5
# 0  2012-01-31   97139.250000   97139.250000  27   3597.750000  long
# 1  2012-03-15   98326.801270   98326.801270  26   3781.800049  long
# 2  2012-03-19   98072.000000   98072.000000  26   3772.000000  long
# 3  2012-04-24  104198.897461  104198.897461  26   4007.649902  long
# 4  2012-05-02  103561.897461  103561.897461  26   3983.149902  long
# ..        ...            ...            ...  ..           ...   ...
# 87 2021-04-20  715814.560547  715814.560547  27  26511.650391  long
# 88 2021-04-23  712206.000000  712206.000000  27  26378.000000  long
# 89 2021-09-02  711748.472656  711748.472656  29  24543.050781  long
# 90 2021-09-06  710391.250000  710391.250000  29  24496.250000  long
# 91 2021-09-29  715883.861328  715883.861328  29  24685.650391  long
#
# [92 rows x 6 columns]

# %%
qa.columns=['Date','Currentvalue','P/L','Noofshares','indexprice','Strategy']

# %%
qa
# Out:
#          Date   Currentvalue            P/L  Noofshares    indexprice Strategy
# 0  2012-01-31   97139.250000   97139.250000          27   3597.750000     long
# 1  2012-03-15   98326.801270   98326.801270          26   3781.800049     long
# 2  2012-03-19   98072.000000   98072.000000          26   3772.000000     long
# 3  2012-04-24  104198.897461  104198.897461          26   4007.649902     long
# 4  2012-05-02  103561.897461  103561.897461          26   3983.149902     long
# ..        ...            ...            ...         ...           ...      ...
# 87 2021-04-20  715814.560547  715814.560547          27  26511.650391     long
# 88 2021-04-23  712206.000000  712206.000000          27  26378.000000     long
# 89 2021-09-02  711748.472656  711748.472656          29  24543.050781     long
# 90 2021-09-06  710391.250000  710391.250000          29  24496.250000     long
# 91 2021-09-29  715883.861328  715883.861328          29  24685.650391     long
#
# [92 rows x 6 columns]
