# %%
 pip install yfinance

# %%
 pip install yfinance
import yfinance as yf
import pandas as pd
import numpy as np

# %%
df=pd.read_csv('ind_nifty500list (4).csv')

# %%
df
# Out:
#                Sym
# 0       3MINDIA.NS
# 1           ABB.NS
# 2    POWERINDIA.NS
# 3           ACC.NS
# 4        AIAENG.NS
# ..             ...
# 496     YESBANK.NS
# 497        ZEEL.NS
# 498  ZENSARTECH.NS
# 499   ZYDUSWELL.NS
# 500      ECLERX.NS
#
# [501 rows x 1 columns]

# %%
tickers=df.Sym.to_list()

# %%
tickers
# Out:
# ['3MINDIA.NS',
#  'ABB.NS',
#  'POWERINDIA.NS',
#  'ACC.NS',
#  'AIAENG.NS',
#  'APLAPOLLO.NS',
#  'AUBANK.NS',
#  'AARTIDRUGS.NS',
#  'AARTIIND.NS',
#  'AAVAS.NS',
#  'ABBOTINDIA.NS',
#  'ADANIENT.NS',
#  'ADANIGREEN.NS',
#  'ADANIPORTS.NS',
#  'ATGL.NS',
#  'ADANITRANS.NS',
#  'ABCAPITAL.NS',
#  'ABFRL.NS',
#  'ADVENZYMES.NS',
#  'AEGISCHEM.NS',
#  'AFFLE.NS',
#  'AJANTPHARM.NS',
#  'AKZOINDIA.NS',
#  'ALEMBICLTD.NS',
#  'APLLTD.NS',
#  'ALKEM.NS',
#  'ALKYLAMINE.NS',
#  'ALOKINDS.NS',
#  'AMARAJABAT.NS',
#  'AMBER.NS',
#  'AMBUJACEM.NS',
#  'ANGELBRKG.NS',
#  'APOLLOHOSP.NS',
#  'APOLLOTYRE.NS',
#  'ASAHIINDIA.NS',
#  'ASHOKLEY.NS',
#  'ASHOKA.NS',
#  'ASIANPAINT.NS',
#  'ASTERDM.NS',
#  'ASTRAZEN.NS',
#  'ASTRAL.NS',
#  'ATUL.NS',
#  'AUROPHARMA.NS',
#  'AVANTIFEED.NS',
#  'DMART.NS',
#  'AXISBANK.NS',
#  'BASF.NS',
#  'BEML.NS',
#  'BSE.NS',
#  'BAJAJ-AUTO.NS',
#  'BAJAJCON.NS',
#  'BAJAJELEC.NS',
#  'BAJFINANCE.NS',
#  'BAJAJFINSV.NS',
#  'BAJAJHLDNG.NS',
#  'BALAMINES.NS',
# ...

# %%
mr=yf.download('^NSEI',start='2011-09-15',interval='1mo')
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
mr=mr['Adj Close']

# %%
mr=pd.DataFrame(mr)

# %%
mr
# Out:
#                Adj Close
# Date
# 2011-10-01   5326.600098
# 2011-11-01   4832.049805
# 2011-12-01   4624.299805
# 2012-01-01   5199.250000
# 2012-02-01   5385.200195
# ...                  ...
# 2021-06-01  15721.500000
# 2021-07-01  15763.049805
# 2021-08-01  17132.199219
# 2021-09-01  17853.199219
# 2021-09-27  17855.099609
#
# [121 rows x 1 columns]

# %%
mret=[0]
for i in range(1,121):
  mret.append((mr['Adj Close'][i]-mr['Adj Close'][i-1])*100/mr['Adj Close'][i])

# %%
mret
# Out:
# [0,
#  -10.234792954513715,
#  -4.492572038461059,
#  11.058329476607202,
#  3.4529857492458444,
#  -1.6929382959564183,
#  -0.9031735606976826,
#  -6.577649435827791,
#  6.7182539715574245,
#  -0.9542914963425129,
#  0.5609964818864696,
#  7.798990407657025,
#  -1.4876168918180377,
#  4.424430861722947,
#  0.4275964773234207,
#  2.1483889530427938,
#  -6.002058774036255,
#  -0.18477620717619783,
#  4.176088200542608,
#  0.93134754184318,
#  -2.460545602585445,
#  -1.7450399740943923,
#  -4.938049726911224,
#  4.5943544186589795,
#  8.951209391706268,
#  -1.9923544428011426,
#  2.0288690092599935,
#  -3.522456687741194,
#  2.9863259939912226,
#  6.37287055208656,
#  -0.11648487370086553,
#  7.379722937990286,
#  5.010936265580449,
#  1.4239792497695916,
#  2.9298470661659497,
#  0.13119861499971494,
#  4.2945420950857045,
#  3.097834887054988,
#  -3.689012006741744,
#  5.973506022074176,
#  0.40362730170577693,
#  -4.164404774172653,
#  -3.7829248915235594,
#  2.9898131763357774,
# ...

# %%
mret
# Out:
# [0,
#  -10.234792954513715,
#  -4.492572038461059,
#  11.058329476607202,
#  3.4529857492458444,
#  -1.6929382959564183,
#  -0.9031735606976826,
#  -6.577649435827791,
#  6.7182539715574245,
#  -0.9542914963425129,
#  0.5609964818864696,
#  7.798990407657025,
#  -1.4876168918180377,
#  4.424430861722947,
#  0.4275964773234207,
#  2.1483889530427938,
#  -6.002058774036255,
#  -0.18477620717619783,
#  4.176088200542608,
#  0.93134754184318,
#  -2.460545602585445,
#  -1.7450399740943923,
#  -4.938049726911224,
#  4.5943544186589795,
#  8.951209391706268,
#  -1.9923544428011426,
#  2.0288690092599935,
#  -3.522456687741194,
#  2.9863259939912226,
#  6.37287055208656,
#  -0.11648487370086553,
#  7.379722937990286,
#  5.010936265580449,
#  1.4239792497695916,
#  2.9298470661659497,
#  0.13119861499971494,
#  4.2945420950857045,
#  3.097834887054988,
#  -3.689012006741744,
#  5.973506022074176,
#  0.40362730170577693,
#  -4.164404774172653,
#  -3.7829248915235594,
#  2.9898131763357774,
# ...

# %%
mr['monthly returns']=mret

# %%
mr
# Out:
#                Adj Close  monthly returns
# Date
# 2011-10-01   5326.600098         0.000000
# 2011-11-01   4832.049805       -10.234793
# 2011-12-01   4624.299805        -4.492572
# 2012-01-01   5199.250000        11.058329
# 2012-02-01   5385.200195         3.452986
# ...                  ...              ...
# 2021-06-01  15721.500000         0.882233
# 2021-07-01  15763.049805         0.263590
# 2021-08-01  17132.199219         7.991673
# 2021-09-01  17853.199219         4.038492
# 2021-09-27  17855.099609         0.010643
#
# [121 rows x 2 columns]

# %%
b=[]
for t in tickers:
  a=yf.download(t,start='2011-09-15',interval='1mo')
  b.append(a['Adj Close'])
c=pd.DataFrame(b)
# Out:
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# ...

# %%
b
# Out:
# [Date
#  2011-10-01     4270.100098
#  2011-11-01     3814.600098
#  2011-12-01     3544.050049
#  2012-01-01     3597.750000
#  2012-02-01     3800.000000
#                    ...
#  2021-06-01    24331.550781
#  2021-07-01    24660.900391
#  2021-08-01    24391.449219
#  2021-09-01    24801.150391
#  2021-09-27    25131.699219
#  Name: Adj Close, Length: 121, dtype: float64, Date
#  2011-10-01     667.658325
#  2011-11-01     561.107666
#  2011-12-01     548.552856
#  2012-01-01     767.672974
#  2012-02-01     761.748474
#                   ...
#  2021-06-01    1808.199951
#  2021-07-01    1699.150024
#  2021-08-01    1895.750000
#  2021-09-01    1878.699951
#  2021-09-27    1855.000000
#  Name: Adj Close, Length: 127, dtype: float64, Date
#  2020-04-01     799.580505
#  2020-05-01     815.343567
#  2020-06-01     838.289917
#  2020-07-01     894.757874
#  2020-08-01     915.110352
#  2020-09-01     922.193726
#  2020-10-01     962.050598
#  2020-11-01    1137.091309
# ...

# %%
c=pd.DataFrame(b)

# %%
c
# Out:
# Date       2011-09-01  2011-09-15  ...  2021-09-24    2021-09-27
# Adj Close         NaN         NaN  ...         NaN  25131.699219
# Adj Close         NaN         NaN  ...         NaN   1855.000000
# Adj Close         NaN         NaN  ...         NaN   2300.399902
# Adj Close         NaN         NaN  ...         NaN   2331.850098
# Adj Close         NaN         NaN  ...         NaN   1980.050049
# ...               ...         ...  ...         ...           ...
# Adj Close         NaN         NaN  ...         NaN           NaN
# Adj Close         NaN         NaN  ...         NaN           NaN
# Adj Close         NaN         NaN  ...         NaN           NaN
# Adj Close         NaN         NaN  ...         NaN           NaN
# Adj Close         NaN         NaN  ...         NaN           NaN
#
# [501 rows x 1425 columns]

# %%
c.dropna(how='all',axis=1,inplace=True)
c.dropna(how='all',axis=0,inplace=True)

# %%
c
# Out:
# Date       2011-09-01   2011-10-01  ...   2021-09-22    2021-09-27
# Adj Close         NaN  4270.100098  ...          NaN  25131.699219
# Adj Close         NaN   667.658325  ...          NaN   1855.000000
# Adj Close         NaN          NaN  ...          NaN   2300.399902
# Adj Close         NaN  1004.578918  ...          NaN   2331.850098
# Adj Close         NaN   284.236908  ...          NaN   1980.050049
# ...               ...          ...  ...          ...           ...
# Adj Close         NaN    46.614086  ...    13.150000           NaN
# Adj Close         NaN   112.779373  ...   336.799988           NaN
# Adj Close         NaN    14.099954  ...   514.450012           NaN
# Adj Close         NaN   522.794556  ...  2369.850098           NaN
# Adj Close         NaN   464.208740  ...  2287.850098           NaN
#
# [501 rows x 123 columns]

# %%
c.isna().sum().sum()
# Out:
# 10337

# %%
c=c.reset_index()

# %%
c
# Out:
# Date      index  2011-09-01 00:00:00  ...  2021-09-22 00:00:00  2021-09-27 00:00:00
# 0     Adj Close                  NaN  ...                  NaN         25131.699219
# 1     Adj Close                  NaN  ...                  NaN          1855.000000
# 2     Adj Close                  NaN  ...                  NaN          2300.399902
# 3     Adj Close                  NaN  ...                  NaN          2331.850098
# 4     Adj Close                  NaN  ...                  NaN          1980.050049
# ..          ...                  ...  ...                  ...                  ...
# 496   Adj Close                  NaN  ...            13.150000                  NaN
# 497   Adj Close                  NaN  ...           336.799988                  NaN
# 498   Adj Close                  NaN  ...           514.450012                  NaN
# 499   Adj Close                  NaN  ...          2369.850098                  NaN
# ...

# %%
c.drop('index',axis=1,inplace=True)

# %%
c
# Out:
# Date  2011-09-01   2011-10-01  ...   2021-09-22    2021-09-27
# 0            NaN  4270.100098  ...          NaN  25131.699219
# 1            NaN   667.658325  ...          NaN   1855.000000
# 2            NaN          NaN  ...          NaN   2300.399902
# 3            NaN  1004.578918  ...          NaN   2331.850098
# 4            NaN   284.236908  ...          NaN   1980.050049
# ..           ...          ...  ...          ...           ...
# 496          NaN    46.614086  ...    13.150000           NaN
# 497          NaN   112.779373  ...   336.799988           NaN
# 498          NaN    14.099954  ...   514.450012           NaN
# 499          NaN   522.794556  ...  2369.850098           NaN
# 500          NaN   464.208740  ...  2287.850098           NaN
#
# [501 rows x 123 columns]

# %%
c.index=tickers

# %%
c
# Out:
# Date           2011-09-01   2011-10-01  ...   2021-09-22    2021-09-27
# 3MINDIA.NS            NaN  4270.100098  ...          NaN  25131.699219
# ABB.NS                NaN   667.658325  ...          NaN   1855.000000
# POWERINDIA.NS         NaN          NaN  ...          NaN   2300.399902
# ACC.NS                NaN  1004.578918  ...          NaN   2331.850098
# AIAENG.NS             NaN   284.236908  ...          NaN   1980.050049
# ...                   ...          ...  ...          ...           ...
# YESBANK.NS            NaN    46.614086  ...    13.150000           NaN
# ZEEL.NS               NaN   112.779373  ...   336.799988           NaN
# ZENSARTECH.NS         NaN    14.099954  ...   514.450012           NaN
# ZYDUSWELL.NS          NaN   522.794556  ...  2369.850098           NaN
# ECLERX.NS             NaN   464.208740  ...  2287.850098           NaN
#
# [501 rows x 123 columns]

# %%
c.iloc[:,1]
# Out:
# 3MINDIA.NS       4270.100098
# ABB.NS            667.658325
# POWERINDIA.NS            NaN
# ACC.NS           1004.578918
# AIAENG.NS         284.236908
#                     ...
# YESBANK.NS         46.614086
# ZEEL.NS           112.779373
# ZENSARTECH.NS      14.099954
# ZYDUSWELL.NS      522.794556
# ECLERX.NS         464.208740
# Name: 2011-10-01 00:00:00, Length: 501, dtype: float64

# %%
c=c[c.iloc[:,1]>0]

# %%
c
# Out:
# Date           2011-09-01   2011-10-01  ...   2021-09-22    2021-09-27
# 3MINDIA.NS            NaN  4270.100098  ...          NaN  25131.699219
# ABB.NS                NaN   667.658325  ...          NaN   1855.000000
# ACC.NS                NaN  1004.578918  ...          NaN   2331.850098
# AIAENG.NS             NaN   284.236908  ...          NaN   1980.050049
# AARTIDRUGS.NS         NaN    10.484313  ...          NaN    609.599976
# ...                   ...          ...  ...          ...           ...
# YESBANK.NS            NaN    46.614086  ...    13.150000           NaN
# ZEEL.NS               NaN   112.779373  ...   336.799988           NaN
# ZENSARTECH.NS         NaN    14.099954  ...   514.450012           NaN
# ZYDUSWELL.NS          NaN   522.794556  ...  2369.850098           NaN
# ECLERX.NS             NaN   464.208740  ...  2287.850098           NaN
#
# [365 rows x 123 columns]

# %%
c.isna().sum().sum()
# Out:
# 774

# %%
c.dropna(how='all',axis=0,inplace=True)
c.dropna(how='all',axis=0,inplace=True)

c.isna().sum().sum()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# 774

# %%
c
# Out:
# Date           2011-09-01   2011-10-01  ...   2021-09-22    2021-09-27
# 3MINDIA.NS            NaN  4270.100098  ...          NaN  25131.699219
# ABB.NS                NaN   667.658325  ...          NaN   1855.000000
# ACC.NS                NaN  1004.578918  ...          NaN   2331.850098
# AIAENG.NS             NaN   284.236908  ...          NaN   1980.050049
# AARTIDRUGS.NS         NaN    10.484313  ...          NaN    609.599976
# ...                   ...          ...  ...          ...           ...
# YESBANK.NS            NaN    46.614086  ...    13.150000           NaN
# ZEEL.NS               NaN   112.779373  ...   336.799988           NaN
# ZENSARTECH.NS         NaN    14.099954  ...   514.450012           NaN
# ZYDUSWELL.NS          NaN   522.794556  ...  2369.850098           NaN
# ECLERX.NS             NaN   464.208740  ...  2287.850098           NaN
#
# [365 rows x 123 columns]

# %%
c=c.iloc[:,1:]

# %%
for i in range(0,120):
  c=c[c.iloc[:,i]>0]

# %%
c
# Out:
# Date            2011-10-01   2011-11-01  ...   2021-09-22    2021-09-27
# 3MINDIA.NS     4270.100098  3814.600098  ...          NaN  25131.699219
# ABB.NS          667.658325   561.107666  ...          NaN   1855.000000
# ACC.NS         1004.578918   961.917603  ...          NaN   2331.850098
# AIAENG.NS       284.236908   251.937271  ...          NaN   1980.050049
# AARTIDRUGS.NS    10.484313     8.432351  ...          NaN    609.599976
# ...                    ...          ...  ...          ...           ...
# YESBANK.NS       46.614086    40.370205  ...    13.150000           NaN
# ZEEL.NS         112.779373   115.369873  ...   336.799988           NaN
# ZENSARTECH.NS    14.099954    13.402672  ...   514.450012           NaN
# ZYDUSWELL.NS    522.794556   407.462189  ...  2369.850098           NaN
# ECLERX.NS       464.208740   451.562134  ...  2287.850098           NaN
#
# [361 rows x 122 columns]

# %%
c.isna().sum().sum()
# Out:
# 361

# %%
cl=[i for i in range(len(c.columns))]
c2=[i for i in range(len(c))]

# %%
c.columns=cl

# %%
c=pd.DataFrame(c)

# %%
c
# Out:
#                        0            1    ...          120           121
# 3MINDIA.NS     4270.100098  3814.600098  ...          NaN  25131.699219
# ABB.NS          667.658325   561.107666  ...          NaN   1855.000000
# ACC.NS         1004.578918   961.917603  ...          NaN   2331.850098
# AIAENG.NS       284.236908   251.937271  ...          NaN   1980.050049
# AARTIDRUGS.NS    10.484313     8.432351  ...          NaN    609.599976
# ...                    ...          ...  ...          ...           ...
# YESBANK.NS       46.614086    40.370205  ...    13.150000           NaN
# ZEEL.NS         112.779373   115.369873  ...   336.799988           NaN
# ZENSARTECH.NS    14.099954    13.402672  ...   514.450012           NaN
# ZYDUSWELL.NS    522.794556   407.462189  ...  2369.850098           NaN
# ECLERX.NS       464.208740   451.562134  ...  2287.850098           NaN
#
# [361 rows x 122 columns]

# %%
c.isna().sum().sum()
# Out:
# 361

# %%
c.drop(labels=120,axis=1,inplace=True)
c.drop(labels=121,axis=1,inplace=True)

# %%
c=c[:119]

# %%
c
# Out:
#                        0            1    ...           118           119
# 3MINDIA.NS     4270.100098  3814.600098  ...  24391.449219  24801.150391
# ABB.NS          667.658325   561.107666  ...   1895.750000   1878.699951
# ACC.NS         1004.578918   961.917603  ...   2413.199951   2298.750000
# AIAENG.NS       284.236908   251.937271  ...   2012.111694   1943.400024
# AARTIDRUGS.NS    10.484313     8.432351  ...    616.150024    613.799988
# ...                    ...          ...  ...           ...           ...
# YESBANK.NS       46.614086    40.370205  ...     10.800000     12.850000
# ZEEL.NS         112.779373   115.369873  ...    169.181625    314.314148
# ZENSARTECH.NS    14.099954    13.402672  ...    448.081543    506.741119
# ZYDUSWELL.NS    522.794556   407.462189  ...   2313.800049   2352.100098
# ECLERX.NS       464.208740   451.562134  ...   2262.938477   2279.730957
#
# [361 rows x 120 columns]

# %%
c.isna().sum().sum()
# Out:
# 0

# %%
sss=c.index

# %%
sss
# Out:
# Index(['3MINDIA.NS', 'ABB.NS', 'ACC.NS', 'AIAENG.NS', 'AARTIDRUGS.NS',
#        'AARTIIND.NS', 'ABBOTINDIA.NS', 'ADANIENT.NS', 'ADANIPORTS.NS',
#        'AEGISCHEM.NS',
#        ...
#        'WELCORP.NS', 'WELSPUNIND.NS', 'WHIRLPOOL.NS', 'WIPRO.NS',
#        'WOCKPHARMA.NS', 'YESBANK.NS', 'ZEEL.NS', 'ZENSARTECH.NS',
#        'ZYDUSWELL.NS', 'ECLERX.NS'],
#       dtype='object', length=361)

# %%
len(sss)
# Out:
# 361

# %%
import yfinance as yf

data = pd.DataFrame()
for t in sss:
    a=yf.download(t,start='2011-09-15',interval='1mo')
    data[t]=a['Adj Close']
    
sec_returns = np.log( data / data.shift(1))
# Out:
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# ...

# %%
sec_returns
# Out:
#             3MINDIA.NS    ABB.NS  ...  ZYDUSWELL.NS  ECLERX.NS
# Date                              ...
# 2011-10-01         NaN       NaN  ...           NaN        NaN
# 2011-11-01   -0.112801 -0.173863  ...     -0.249240  -0.027621
# 2011-12-01   -0.073566 -0.022630  ...     -0.138159  -0.051681
# 2012-01-01    0.015038  0.336080  ...      0.070134   0.042001
# 2012-02-01    0.054692 -0.007747  ...     -0.101631   0.051127
# ...                ...       ...  ...           ...        ...
# 2021-06-01   -0.048321  0.080197  ...      0.002168   0.430658
# 2021-07-01    0.013443 -0.062204  ...      0.018979   0.146928
# 2021-08-01   -0.010988  0.109486  ...      0.082185   0.008294
# 2021-09-01    0.016661 -0.009035  ...      0.016417   0.007393
# 2021-09-22   -0.003103 -0.005096  ...      0.007518   0.003555
#
# [121 rows x 361 columns]

# %%
mret=[0]
for i in range(1,121):
  mret.append((mr['Adj Close'][i]-mr['Adj Close'][i-1])*100/mr['Adj Close'][i])

# %%
mret
# Out:
# [0,
#  -10.234792954513715,
#  -4.492572038461059,
#  11.058329476607202,
#  3.4529857492458444,
#  -1.6929382959564183,
#  -0.9031735606976826,
#  -6.577649435827791,
#  6.7182539715574245,
#  -0.9542914963425129,
#  0.5609964818864696,
#  7.798990407657025,
#  -1.4876168918180377,
#  4.424430861722947,
#  0.4275964773234207,
#  2.1483889530427938,
#  -6.002058774036255,
#  -0.18477620717619783,
#  4.176088200542608,
#  0.93134754184318,
#  -2.460545602585445,
#  -1.7450399740943923,
#  -4.938049726911224,
#  4.5943544186589795,
#  8.951209391706268,
#  -1.9923544428011426,
#  2.0288690092599935,
#  -3.522456687741194,
#  2.9863259939912226,
#  6.37287055208656,
#  -0.11648487370086553,
#  7.379722937990286,
#  5.010936265580449,
#  1.4239792497695916,
#  2.9298470661659497,
#  0.13119861499971494,
#  4.2945420950857045,
#  3.097834887054988,
#  -3.689012006741744,
#  5.973506022074176,
#  0.40362730170577693,
#  -4.164404774172653,
#  -3.7829248915235594,
#  2.9898131763357774,
# ...

# %%
mr['monthly returns']=mret

# %%
mr
# Out:
#                Adj Close  monthly returns
# Date
# 2011-10-01   5326.600098         0.000000
# 2011-11-01   4832.049805       -10.234793
# 2011-12-01   4624.299805        -4.492572
# 2012-01-01   5199.250000        11.058329
# 2012-02-01   5385.200195         3.452986
# ...                  ...              ...
# 2021-06-01  15721.500000         0.882233
# 2021-07-01  15763.049805         0.263590
# 2021-08-01  17132.199219         7.991673
# 2021-09-01  17853.199219         4.038492
# 2021-09-27  17855.099609         0.010643
#
# [121 rows x 2 columns]

# %%
infos=[]
for i in sss:
  infos.append(yf.Ticker(i).info)

# %%
infos=pd.DataFrame(infos)

# %%
infos
# Out:
#          zip  ...                                        logo_url
# 0     560001  ...            https://logo.clearbit.com/3mindia.in
# 1     560058  ...           https://logo.clearbit.com/new.abb.com
# 2     400020  ...        https://logo.clearbit.com/acclimited.com
# 3     380054  ...    https://logo.clearbit.com/aiaengineering.com
# 4    400 022  ...      https://logo.clearbit.com/aartidrugs.co.in
# ..       ...  ...                                             ...
# 356   400055  ...            https://logo.clearbit.com/yesbank.in
# 357   400013  ...  https://logo.clearbit.com/zeeentertainment.com
# 358   411014  ...            https://logo.clearbit.com/zensar.com
# 359   382481  ...      https://logo.clearbit.com/zyduswellness.in
# 360   400021  ...            https://logo.clearbit.com/eclerx.com
#
# [361 rows x 153 columns]

# %%
beta=infos['beta']

# %%
beta.dropna(axis=0,how=all,inplace=True)

# %%
beta
# Out:
# 0      0.490716
# 1      0.963212
# 2      0.670203
# 3      0.525641
# 4      1.065116
#          ...
# 356    1.157674
# 357    0.951547
# 358    0.950394
# 359    0.227441
# 360    1.066397
# Name: beta, Length: 355, dtype: float64

# %%
len(beta)
# Out:
# 355

# %%
c
# Out:
#                        0            1    ...           118           119
# 3MINDIA.NS     4270.100098  3814.600098  ...  24391.449219  24801.150391
# ABB.NS          667.658325   561.107666  ...   1895.750000   1878.699951
# ACC.NS         1004.578918   961.917603  ...   2413.199951   2298.750000
# AIAENG.NS       284.236908   251.937271  ...   2012.111694   1943.400024
# AARTIDRUGS.NS    10.484313     8.432351  ...    616.150024    613.799988
# ...                    ...          ...  ...           ...           ...
# YESBANK.NS       46.614086    40.370205  ...     10.800000     12.850000
# ZEEL.NS         112.779373   115.369873  ...    169.181625    314.314148
# ZENSARTECH.NS    14.099954    13.402672  ...    448.081543    506.741119
# ZYDUSWELL.NS    522.794556   407.462189  ...   2313.800049   2352.100098
# ECLERX.NS       464.208740   451.562134  ...   2262.938477   2279.730957
#
# [361 rows x 120 columns]

# %%
c.index=c2

# %%
c=pd.DataFrame(c)

# %%
c
# Out:
#              0            1    ...           118           119
# 0    4270.100098  3814.600098  ...  24391.449219  24801.150391
# 1     667.658325   561.107666  ...   1895.750000   1878.699951
# 2    1004.578918   961.917603  ...   2413.199951   2298.750000
# 3     284.236908   251.937271  ...   2012.111694   1943.400024
# 4      10.484313     8.432351  ...    616.150024    613.799988
# ..           ...          ...  ...           ...           ...
# 356    46.614086    40.370205  ...     10.800000     12.850000
# 357   112.779373   115.369873  ...    169.181625    314.314148
# 358    14.099954    13.402672  ...    448.081543    506.741119
# 359   522.794556   407.462189  ...   2313.800049   2352.100098
# 360   464.208740   451.562134  ...   2262.938477   2279.730957
#
# [361 rows x 120 columns]

# %%
len(c.columns)
# Out:
# 120

# %%
len(c)
# Out:
# 361

# %%
c.isna().sum().sum()
# Out:
# 0

# %%
t=10000000
s=10000000

# %%
print(10000000000000)
# Out:
# 10000000000000

# %%
beta[0]
# Out:
# 0.490716

# %%
mret[1]
# Out:
# -10.234792954513715

# %%
sss[3]
# Out:
# 'AIAENG.NS'

# %%
sec_returns[sss[2]].std() * 250 ** 0.5
# Out:
# 1.2930198462349431

# %%
for i in range(0,len(c.columns)-3):
  sharpe=[]
  for j in range(0,len(c)):
    try:
      abc=beta[j]*(int(mret[i]) - 0.02) / (sec_returns[sss[j]].std() * 250 ** 0.5)
      sharpe.append([j,abc])
    except KeyError:
      sharpe.append([j,0])
  sh= sorted(sharpe, key=lambda x: x[1])
  abcd=sh[-20:]
  for k in range(0,20):
    d=c[i]
    e=c[i+1]
    s=s+((t/(d[abcd[k][0]]*20))*e[abcd[k][0]])-t/20
    print(s)
  t=s
# Out:
# 10117633.698225737
# 10081489.068152804
# 10037009.699916422
# 9917242.275868366
# 9858140.65151557
# 9446837.643705785
# 9392542.250561144
# 9340686.59467125
# 9324128.207031522
# 9287180.92945036
# 9185805.084059935
# 9120548.082640236
# 9076847.783249825
# 9083729.400285318
# 9112135.619262956
# 8871699.51808749
# 8876554.664878258
# 8874045.033151073
# 8877984.367296023
# 8847823.502435854
# 8677165.713688008
# 8676723.790044405
# 8623890.559643066
# 8594578.142477918
# 8579159.654784642
# 8543189.423483826
# 8523548.794355797
# 8469814.568376375
# 8442200.563351762
# 8433164.185125006
# 8422315.386234447
# 8441683.395739248
# 8445434.950045737
# 8478177.488636024
# 8493788.741620442
# 8493462.698950944
# 8491878.565636596
# 8478499.752541037
# 8425843.509419536
# 8385138.558377844
# 8438054.42487971
# 8477883.857325017
# 8524108.538736425
# 8593221.921150729
# 8640970.623812033
# 8765291.363278868
# 8837028.218295202
# 8857667.227453694
# 8860386.849791853
# 8849076.133681685
# ...

# %%
s
# Out:
# 257119482.07467118
