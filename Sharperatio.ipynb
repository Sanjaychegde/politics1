# %%
pip install yfinance
# Out:
# ...
#      |████████████████████████████████| 6.4 MB 5.3 MB/s
# ...
#   Attempting uninstall: lxml
#     Found existing installation: lxml 4.2.6
#     Uninstalling lxml-4.2.6:
#       Successfully uninstalled lxml-4.2.6
# ...

# %%
import yfinance as yf
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df=pd.read_csv('nse.csv')

# %%
a=df['Sym'].to_list()
d=[]
c=[]

# %%
for i in range(0,len(a)):
  b=yf.download(a[i],start='2006-01-02',end='2006-01-04',interval='1d')
  c.append(a[i])
  d.append(b['Adj Close'])
# Out:
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - 20MICRONS.NS: Data doesn't exist for startDate = 1136160000, endDate = 1136332800
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - 21STCENMGM.NS: Data doesn't exist for startDate = 1136160000, endDate = 1136332800
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - 3IINFOTECH.NS: No data found, symbol may be delisted
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - 3PLAND.NS: Data doesn't exist for startDate = 1136160000, endDate = 1136332800
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - 5PAISA.NS: Data doesn't exist for startDate = 1136160000, endDate = 1136332800
# ...

# %%
d
# Out:
# [Series([], Name: Adj Close, dtype: float64),
#  Series([], Name: Adj Close, dtype: float64),
#  Series([], Name: Adj Close, dtype: float64),
#  Date
#  2006-01-02    857.700012
#  2006-01-03    890.000000
#  Name: Adj Close, dtype: float64,
#  Series([], Name: Adj Close, dtype: float64),
#  Series([], Name: Adj Close, dtype: float64),
#  Date
#  2006-01-02    928.006470
#  2006-01-03    920.308838
#  Name: Adj Close, dtype: float64,
#  Series([], Name: Adj Close, dtype: float64),
#  Date
#  2006-01-02    8.809668
#  2006-01-03    9.080931
#  Name: Adj Close, dtype: float64,
#  Date
#  2006-01-02    11.383929
#  2006-01-03    11.569281
#  Name: Adj Close, dtype: float64,
#  Series([], Name: Adj Close, dtype: float64),
#  Series([], Name: Adj Close, dtype: float64),
#  Date
#  2006-01-02    540.740112
#  2006-01-03    548.462891
#  Name: Adj Close, dtype: float64,
#  Date
#  2006-01-02    69.608727
#  2006-01-03    71.557373
#  Name: Adj Close, dtype: float64,
#  Date
# ...

# %%
c
# Out:
# ['20MICRONS.NS',
#  '21STCENMGM.NS',
#  '3IINFOTECH.NS',
#  '3MINDIA.NS',
#  '3PLAND.NS',
#  '5PAISA.NS',
#  '63MOONS.NS',
#  'A2ZINFRA.NS',
#  'AARTIDRUGS.NS',
#  'AARTIIND.NS',
#  'AARVEEDEN.NS',
#  'AAVAS.NS',
#  'ABAN.NS',
#  'ABB.NS',
#  'ABBOTINDIA.NS',
#  'ABCAPITAL.NS',
#  'ABFRL.NS',
#  'ABMINTLTD.NS',
#  'ACC.NS',
#  'ACCELYA.NS',
#  'ACE.NS',
#  'ADANIENT.NS',
#  'ADANIGAS.NS',
#  'ADANIGREEN.NS',
#  'ADANIPORTS.NS',
#  'ADANIPOWER.NS',
#  'ADANITRANS.NS',
#  'ADFFOODS.NS',
#  'ADHUNIK.NS',
#  'ADHUNIKIND.NS',
#  'ADLABS.NS',
#  'ADORWELD.NS',
#  'ADROITINFO.NS',
#  'ADSL.NS',
#  'ADVANIHOTR.NS',
#  'ADVENZYMES.NS',
#  'AEGISCHEM.NS',
#  'AFFLE.NS',
#  'AGARIND.NS',
#  'AGCNET.NS',
#  'AGRITECH.NS',
#  'AGROPHOS.NS',
#  'AHLEAST.NS',
#  'AHLUCONT.NS',
#  'AHLWEST.NS',
#  'AIAENG.NS',
#  'AIONJSW.NS',
#  'AIRAN.NS',
#  'AJANTPHARM.NS',
#  'AJMERA.NS',
#  'AKASH.NS',
#  'AKSHARCHEM.NS',
#  'AKSHOPTFBR.NS',
#  'AKZOINDIA.NS',
#  'ALANKIT.NS',
#  'ALBERTDAVD.NS',
# ...

# %%
len(c)
# Out:
# 1641

# %%
f=pd.DataFrame(d)

# %%
f
# Out:
# Date       2006-01-02 00:00:00  2006-01-03 00:00:00  2006-01-04 00:00:00
# Adj Close                  NaN                  NaN                  NaN
# Adj Close                  NaN                  NaN                  NaN
# Adj Close                  NaN                  NaN                  NaN
# Adj Close           857.700012           890.000000                  NaN
# Adj Close                  NaN                  NaN                  NaN
# ...                        ...                  ...                  ...
# Adj Close            53.127235            55.797340                  NaN
# Adj Close                  NaN                  NaN                  NaN
# Adj Close                  NaN                  NaN                  NaN
# Adj Close           112.418213           115.408104                  NaN
# Adj Close                  NaN                  NaN                  NaN
#
# [1641 rows x 3 columns]

# %%
f.iloc[:,1]
# Out:
# Adj Close           NaN
# Adj Close           NaN
# Adj Close           NaN
# Adj Close    890.000000
# Adj Close           NaN
#                 ...
# Adj Close     55.797340
# Adj Close           NaN
# Adj Close           NaN
# Adj Close    115.408104
# Adj Close           NaN
# Name: 2006-01-03 00:00:00, Length: 1641, dtype: float64

# %%
f.index=c

# %%
f
# Out:
# Date           2006-01-02 00:00:00  2006-01-03 00:00:00  2006-01-04 00:00:00
# 20MICRONS.NS                   NaN                  NaN                  NaN
# 21STCENMGM.NS                  NaN                  NaN                  NaN
# 3IINFOTECH.NS                  NaN                  NaN                  NaN
# 3MINDIA.NS              857.700012           890.000000                  NaN
# 3PLAND.NS                      NaN                  NaN                  NaN
# ...                            ...                  ...                  ...
# ZODJRDMKJ.NS             53.127235            55.797340                  NaN
# ZOTA.NS                        NaN                  NaN                  NaN
# ZUARI.NS                       NaN                  NaN                  NaN
# ZUARIGLOB.NS            112.418213           115.408104                  NaN
# ZYDUSWELL.NS                   NaN                  NaN                  NaN
#
# [1641 rows x 3 columns]

# %%
f=f.iloc[:,1]

# %%
l=pd.DataFrame(f)

# %%
l
# Out:
#                2006-01-03
# 20MICRONS.NS          NaN
# 21STCENMGM.NS         NaN
# 3IINFOTECH.NS         NaN
# 3MINDIA.NS     890.000000
# 3PLAND.NS             NaN
# ...                   ...
# ZODJRDMKJ.NS    55.797340
# ZOTA.NS               NaN
# ZUARI.NS              NaN
# ZUARIGLOB.NS   115.408104
# ZYDUSWELL.NS          NaN
#
# [1641 rows x 1 columns]

# %%
l=l[l.iloc[:,0]>0]

# %%
l
# Out:
#                2006-01-03
# 3MINDIA.NS     890.000000
# 63MOONS.NS     920.308838
# AARTIDRUGS.NS    9.080931
# AARTIIND.NS     11.569281
# ABAN.NS        548.462891
# ...                   ...
# ZENITHEXPO.NS   82.949997
# ZENSARTECH.NS    2.427053
# ZODIACLOTH.NS   97.612961
# ZODJRDMKJ.NS    55.797340
# ZUARIGLOB.NS   115.408104
#
# [684 rows x 1 columns]

# %%
l.to_csv('aqwer.csv')

# %%
df1=pd.read_csv('aqwer.csv')

# %%
df1
# Out:
#         Unnamed: 0  2006-01-03
# 0       3MINDIA.NS  890.000000
# 1       63MOONS.NS  920.308838
# 2    AARTIDRUGS.NS    9.080931
# 3      AARTIIND.NS   11.569281
# 4          ABAN.NS  548.462891
# ..             ...         ...
# 679  ZENITHEXPO.NS   82.949997
# 680  ZENSARTECH.NS    2.427053
# 681  ZODIACLOTH.NS   97.612961
# 682   ZODJRDMKJ.NS   55.797340
# 683   ZUARIGLOB.NS  115.408104
#
# [684 rows x 2 columns]

# %%
q=df1.iloc[:,0]

# %%
q
# Out:
# 0         3MINDIA.NS
# 1         63MOONS.NS
# 2      AARTIDRUGS.NS
# 3        AARTIIND.NS
# 4            ABAN.NS
#            ...
# 679    ZENITHEXPO.NS
# 680    ZENSARTECH.NS
# 681    ZODIACLOTH.NS
# 682     ZODJRDMKJ.NS
# 683     ZUARIGLOB.NS
# Name: Unnamed: 0, Length: 684, dtype: object

# %%
q

# %%
len(q)
# Out:
# 684

# %%
q[1]
qw=[]

# %%
len(q)
s=0

# %%
for i in range(0,len(q)):
  b1=yf.download(q[i],start='2006-01-02',interval='1d')
  s=s+1
  qw.append(b1['Adj Close'])
# Out:
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# ...

# %%
qw

# %%
ssss=pd.DataFrame(qw)

# %%
ssss
# Out:
# Date       2006-01-02  2006-01-03  ...    2021-12-20    2021-12-21
# Adj Close  857.700012  890.000000  ...  23812.949219  24181.250000
# Adj Close  928.006226  920.308777  ...    177.149994    186.000000
# Adj Close    8.809667    9.080930  ...    515.200012    517.200012
# Adj Close   11.383931   11.569280  ...    909.799988    927.299988
# Adj Close  540.740112  548.462952  ...     44.549999     45.400002
# ...               ...         ...  ...           ...           ...
# Adj Close   79.349998   82.949997  ...     87.250000     84.050003
# Adj Close    2.400525    2.427053  ...    449.850006    460.500000
# Adj Close   94.829979   97.612961  ...    103.699997    105.750000
# Adj Close   53.127235   55.797340  ...           NaN           NaN
# Adj Close  112.418213  115.408104  ...    129.100006    130.350006
#
# [684 rows x 3948 columns]

# %%
ssss.index=q

# %%
ssss
# Out:
# Date           2006-01-02  2006-01-03  ...    2021-12-20    2021-12-21
# Unnamed: 0                             ...
# 3MINDIA.NS     857.700012  890.000000  ...  23812.949219  24181.250000
# 63MOONS.NS     928.006226  920.308777  ...    177.149994    186.000000
# AARTIDRUGS.NS    8.809667    9.080930  ...    515.200012    517.200012
# AARTIIND.NS     11.383931   11.569280  ...    909.799988    927.299988
# ABAN.NS        540.740112  548.462952  ...     44.549999     45.400002
# ...                   ...         ...  ...           ...           ...
# ZENITHEXPO.NS   79.349998   82.949997  ...     87.250000     84.050003
# ZENSARTECH.NS    2.400525    2.427053  ...    449.850006    460.500000
# ZODIACLOTH.NS   94.829979   97.612961  ...    103.699997    105.750000
# ZODJRDMKJ.NS    53.127235   55.797340  ...           NaN           NaN
# ZUARIGLOB.NS   112.418213  115.408104  ...    129.100006    130.350006
#
# [684 rows x 3948 columns]

# %%
ssss.columns=range(0,3948)

# %%
ssss
# Out:
#                      0           1     ...          3946          3947
# Unnamed: 0                             ...
# 3MINDIA.NS     857.700012  890.000000  ...  23812.949219  24181.250000
# 63MOONS.NS     928.006226  920.308777  ...    177.149994    186.000000
# AARTIDRUGS.NS    8.809667    9.080930  ...    515.200012    517.200012
# AARTIIND.NS     11.383931   11.569280  ...    909.799988    927.299988
# ABAN.NS        540.740112  548.462952  ...     44.549999     45.400002
# ...                   ...         ...  ...           ...           ...
# ZENITHEXPO.NS   79.349998   82.949997  ...     87.250000     84.050003
# ZENSARTECH.NS    2.400525    2.427053  ...    449.850006    460.500000
# ZODIACLOTH.NS   94.829979   97.612961  ...    103.699997    105.750000
# ZODJRDMKJ.NS    53.127235   55.797340  ...           NaN           NaN
# ZUARIGLOB.NS   112.418213  115.408104  ...    129.100006    130.350006
#
# [684 rows x 3948 columns]

# %%
for i in range(0,632):
  c123=ssss[ssss.iloc[:,i]>0]

# %%
c123
# Out:
#                      0           1     ...          3946          3947
# Unnamed: 0                             ...
# 3MINDIA.NS     857.700012  890.000000  ...  23812.949219  24181.250000
# 63MOONS.NS     928.006226  920.308777  ...    177.149994    186.000000
# AARTIDRUGS.NS    8.809667    9.080930  ...    515.200012    517.200012
# AARTIIND.NS     11.383931   11.569280  ...    909.799988    927.299988
# ABAN.NS        540.740112  548.462952  ...     44.549999     45.400002
# ...                   ...         ...  ...           ...           ...
# ZENITHEXPO.NS   79.349998   82.949997  ...     87.250000     84.050003
# ZENSARTECH.NS    2.400525    2.427053  ...    449.850006    460.500000
# ZODIACLOTH.NS   94.829979   97.612961  ...    103.699997    105.750000
# ZODJRDMKJ.NS    53.127235   55.797340  ...           NaN           NaN
# ZUARIGLOB.NS   112.418213  115.408104  ...    129.100006    130.350006
#
# [678 rows x 3948 columns]

# %%
ind=c123.index

# %%
c123=c123.T

# %%
c123
# Out:
# Unnamed: 0    3MINDIA.NS  63MOONS.NS  ...  ZODJRDMKJ.NS  ZUARIGLOB.NS
# 0             857.700012  928.006226  ...     53.127235    112.418213
# 1             890.000000  920.308777  ...     55.797340    115.408104
# 2             898.700012  906.173340  ...     53.009441    111.740532
# 3             890.049988  896.201477  ...     50.849796    114.650665
# 4             895.049988  906.872620  ...     50.614193    113.215546
# ...                  ...         ...  ...           ...           ...
# 3943        24668.750000  206.550003  ...           NaN    138.399994
# 3944        24926.599609  196.250000  ...           NaN    144.149994
# 3945        24536.099609  186.449997  ...           NaN    136.800003
# 3946        23812.949219  177.149994  ...           NaN    129.100006
# 3947        24181.250000  186.000000  ...           NaN    130.350006
#
# [3948 rows x 678 columns]

# %%
sr11=[]

# %%
sha=c123[:3891-1641-i].pct_change(1).mean()/c123[:3891-1641-i].pct_change(1).std()

# %%
sha
# Out:
# Unnamed: 0
# 3MINDIA.NS       0.051271
# 63MOONS.NS       0.005924
# AARTIDRUGS.NS    0.022423
# AARTIIND.NS      0.020676
# ABAN.NS          0.015245
#                    ...
# ZENITHEXPO.NS    0.006150
# ZENSARTECH.NS    0.055405
# ZODIACLOTH.NS    0.027855
# ZODJRDMKJ.NS     0.007702
# ZUARIGLOB.NS     0.020984
# Length: 678, dtype: float64

# %%
sha.sort_values().tail(20)
# Out:
# Unnamed: 0
# SUNPHARMA.NS     0.058557
# COLPAL.NS        0.059064
# DIVISLAB.NS      0.059361
# CUB.NS           0.059388
# COROMANDEL.NS    0.059503
# GSKCONS.NS       0.060259
# AJANTPHARM.NS    0.061037
# CADILAHC.NS      0.061129
# EICHERMOT.NS     0.062307
# TITAN.NS         0.064005
# SUPREMEIND.NS    0.064480
# VEDL.NS          0.064815
# TATASTLBSL.NS    0.066565
# GENESYS.NS       0.066967
# LUPIN.NS         0.067042
# CRISIL.NS        0.067701
# RALLIS.NS        0.071665
# ASIANPAINT.NS    0.073009
# TTKPRESTIG.NS    0.096531
# BLUEBLENDS.NS         NaN
# dtype: float64

# %%
for i in range(0,1250):
  sha=c123[:3891-2641-i].pct_change(1).mean()*100/c123[:3891-1641-i].pct_change(1).std()
  sr11.append(sha)

# %%
sr11[0].sort_values().tail(20)
# Out:
# Unnamed: 0
# EICHERMOT.NS      6.979858
# CUMMINSIND.NS     7.236276
# EXIDEIND.NS       7.416631
# CUB.NS            7.569563
# SRTRANSFIN.NS     7.648330
# TITAN.NS          7.731033
# NBVENTURES.NS     7.740178
# ASIANPAINT.NS     8.027622
# COROMANDEL.NS     8.052788
# CADILAHC.NS       8.115334
# JINDALSTEL.NS     8.290333
# SUPREMEIND.NS     8.328472
# LUPIN.NS          8.593825
# GENESYS.NS        8.715630
# TATASTLBSL.NS     9.000223
# ADANIENT.NS       9.250427
# VEDL.NS           9.875144
# RALLIS.NS         9.989602
# TTKPRESTIG.NS    11.622905
# BLUEBLENDS.NS          NaN
# dtype: float64

# %%
ROI=[]
min=100000
max=[]
for i in range(0,640,21):
  a=sr11[i].sort_values().tail(10)
  wsd=a.index
  allo=c123[wsd][3891-2641+i:]
  log_ret = np.log(allo/allo.shift(1))
  num_ports = 10000
  all_weights = np.zeros((num_ports,10))
  ret_arr = np.zeros(num_ports)
  vol_arr = np.zeros(num_ports)
  sharpe_arr = np.zeros(num_ports)
  for ind in range(num_ports):
    weights = np.array(np.random.random(10))
    weights = weights / np.sum(weights)
    all_weights[ind,:] = weights
    ret_arr[ind] = np.sum((log_ret.mean() * weights) *252)
    vol_arr[ind] = np.sqrt(np.dot(weights.T, np.dot(log_ret.cov() * 252, weights)))
    sharpe_arr[ind] = ret_arr[ind]/vol_arr[ind]
  allocation=all_weights[sharpe_arr.argmax(),:]
  allo=pd.DataFrame(allo)
  price1=allo.iloc[3890-2641+i]
  price2=allo.iloc[-1]
  price1=price1.fillna(0)
  price2=price2.fillna(0)
  allocation=allocation*10000000
  no_shares=[]
  s=0
  for j in range(0,10):
    no_shares.append(allocation[j]/price1[j])
  for k in range(0,10):
    s=s+no_shares[k]*price2[k]
  if s>min:
    min=s
    max=allocation
  print(s/10000000)
  ROI.append(s/10000000)
  s=0
# Out:
# 12.775107702871038
# 9.484267942708334
# 7.5810036166506665
# 13.26371423050922
# 10.718629773902435
# 11.30194861971782
# 7.221710784751293
# 6.905804995576657
# 8.855060256189105
# 7.208215315149733
# 6.501888741212764
# 5.924456278065983
# 5.385290415048776
# 5.545423750340431
# 7.433412731932762
# 4.05067219396143
# 4.671066173423675
# 3.602806805728889
# 4.066962173043979
# 4.990117811288012
# 4.358666097694871
# 3.597702016822558
# 3.2476095924008863
# 3.5347988980296114
# 4.3653830949941845
# 4.314640825291852
# 4.3789032650590585
# 2.2894284209320066
# 2.027020086186533
# 1.8943793676405556
# 2.3021838133572845

# %%
max
# Out:
# array([1927666.28042798,  491510.62483153,  730295.85594425,
#        1225679.75642195,   87567.25394458, 2642108.28559198,
#         398945.17574809,   89584.82000832, 2375322.16405594,
#          31319.78302538])
